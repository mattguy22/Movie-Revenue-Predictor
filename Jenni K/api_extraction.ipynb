# %%
import requests
import pandas as pd
from time import sleep
import os

# Optionally: Set API key here directly if not using environment variable
api_key = os.getenv("TMDB_API_KEY")

# Fallback if the environment variable is not set
if not api_key:
    api_key = "be93af06df098188cc35a75ee6af6fd4"

# Base TMDB URL
base_url = "https://api.themoviedb.org/3"

# Storage for results
movie_data = []

# Loop through TMDB's /discover/movie endpoint
for page in range(1, 3):  # Start with 2 pages for quick testing; increase to 201 later
    discover_url = f"{base_url}/discover/movie"
    params = {
        "api_key": api_key,
        "language": "en-US",
        "sort_by": "popularity.desc",
        "include_adult": False,
        "include_video": False,
        "page": page,
        "primary_release_date.gte": "2000-01-01",
        "primary_release_date.lte": "2024-12-31"
    }

    response = requests.get(discover_url, params=params)
    if response.status_code != 200:
        print(f"Failed on page {page} — Status: {response.status_code}")
        print(response.json())  # Show error
        break

    movies = response.json().get("results", [])

    for movie in movies:
        movie_id = movie["id"]

        # Fetch movie details
        movie_details = requests.get(f"{base_url}/movie/{movie_id}", params={"api_key": api_key}).json()
        credits = requests.get(f"{base_url}/movie/{movie_id}/credits", params={"api_key": api_key}).json()

        # Get director and top actor
        director = next((c["name"] for c in credits.get("crew", []) if c["job"] == "Director"), None)
        cast = [c["name"] for c in credits.get("cast", [])][:1]

        # Collect relevant fields
        movie_data.append({
            "title": movie_details.get("title"),
            "release_date": movie_details.get("release_date"),
            "budget": movie_details.get("budget"),
            "revenue": movie_details.get("revenue"),
            "runtime": movie_details.get("runtime"),
            "genres": [g["name"] for g in movie_details.get("genres", [])],
            "popularity": movie_details.get("popularity"),
            "vote_average": movie_details.get("vote_average"),
            "vote_count": movie_details.get("vote_count"),
            "original_language": movie_details.get("original_language"),
            "production_companies": [pc["name"] for pc in movie_details.get("production_companies", [])],
            "belongs_to_collection": movie_details.get("belongs_to_collection") is not None,
            "director": director,
            "lead_actor": cast[0] if cast else None
        })

    print(f"Page {page} complete — movies collected: {len(movie_data)}")
    sleep(0.3)

# Convert to DataFrame
df_movies = pd.DataFrame(movie_data)

# Print the DataFrame
df_movies # Preview first few rows
# Out:
# Page 1 complete — movies collected: 20
# Page 2 complete — movies collected: 40
#                                             title release_date     budget  \
# 0                                The Great Escape   2023-05-26     200000
# 1                                   Lilo & Stitch   2002-06-21   80000000
# 2                                   Brave Citizen   2023-10-25          0
# 3                      Bambi: A Life in the Woods   2024-10-16          0
# 4                                         Moana 2   2024-11-21  150000000
# 5                  The Haunting at Saint Joseph's   2023-02-26          0
# 6                              Conjuring the Cult   2024-10-01          0
# 7            Detective Chirp & the Golden Beehive   2022-11-17          0
# 8                           Mufasa: The Lion King   2024-12-18  200000000
# 9   Mission: Impossible - Dead Reckoning Part One   2023-07-08  291000000
# 10                              Final Destination   2000-03-17   23000000
# 11                           Sonic the Hedgehog 3   2024-12-19  122000000
# 12           Lilo & Stitch 2: Stitch Has a Glitch   2005-08-22          0
# 13                            Final Destination 5   2011-08-12   40000000
# 14                                My Massive Cock   2022-10-24          0
# 15                               Stepmom's Desire   2020-05-29          0
# 16                                            xXx   2002-08-09   70000000
# 17                                       My Fault   2023-06-08          0
# 18                               From the Shadows   2023-09-22          0
# 19                                 The Wild Robot   2024-09-12   78000000
# 20                                Saint Catherine   2024-09-24          0
# 21                           Ask Me What You Want   2024-11-29          0
# 22                            Final Destination 2   2003-01-31   26000000
# 23                                         Palmer   2021-01-28          0
# 24                          Venom: The Last Dance   2024-10-22  120000000
# 25                                 Beating Hearts   2024-10-16   37315205
# 26                                      The Siege   2023-03-10          0
# 27                           Deadpool & Wolverine   2024-07-24  200000000
# 28                            Final Destination 3   2006-02-09   25000000
# 29                                 Devara: Part 1   2024-09-26   31764000
# 30                                 Cry of Silence   2024-05-01          0
# 31                                Kung Fu Panda 4   2024-03-02   80000000
# 32                                Despicable Me 4   2024-06-20  100000000
# 33                                  The Substance   2024-09-07   17500000
# 34                                         Stream   2024-02-06          0
# 35                          The Final Destination   2009-08-26   40000000
# 36                                   Inside Out 2   2024-06-11  200000000
# 37                                   Gladiator II   2024-11-13  310000000
# 38                                           Flow   2024-08-29    3700000
# 39                              Kraven the Hunter   2024-12-11  120000000
#
#        revenue  runtime                                             genres  \
# 0            0       90                                 [Action, Thriller]
# 1    273144151       85                        [Animation, Family, Comedy]
# 2      2116112      112                            [Action, Drama, Comedy]
# 3      1419154       77                   [Adventure, Family, Documentary]
# 4   1059544057      100             [Animation, Adventure, Family, Comedy]
# 5            0      100                                 [Horror, Thriller]
# 6            0       93                                    [Horror, Drama]
# 7            0       85    [Animation, Comedy, Mystery, Adventure, Family]
# 8    721046090      118                     [Adventure, Family, Animation]
# 9    571125435      164                      [Action, Adventure, Thriller]
# 10   112880294       98                                           [Horror]
# 11   486018457      110          [Action, Science Fiction, Comedy, Family]
# 12           0       68       [Animation, Family, Comedy, Science Fiction]
# 13   157887643       91                                  [Horror, Mystery]
# 14           0       47                                      [Documentary]
# 15           0       78                                   [Drama, Romance]
# 16   277448382      124               [Action, Adventure, Thriller, Crime]
# 17           0      117                                   [Romance, Drama]
# 18           0       88                [Thriller, Science Fiction, Horror]
# 19   331982078      102               [Animation, Science Fiction, Family]
# 20           0       86                                           [Horror]
# 21     2265661      114                                   [Romance, Drama]
# 22    90941129       90                                  [Horror, Mystery]
# 23           0      110                                            [Drama]
# 24   478103649      109               [Action, Science Fiction, Adventure]
# 25    36010728      166                            [Crime, Drama, Romance]
# 26           0       97                                 [Action, Thriller]
# 27  1338073645      128                  [Action, Comedy, Science Fiction]
# 28   118890272       92                                  [Horror, Mystery]
# 29    49520000      175                                    [Action, Drama]
# 30           0        0                          [Thriller, Drama, Action]
# 31   548040835       94  [Animation, Family, Action, Comedy, Adventure,...
# 32   969280910       94       [Animation, Family, Comedy, Science Fiction]
# 33    76506196      141                          [Horror, Science Fiction]
# 34           0       84                                           [Horror]
# 35   187384627       82                                  [Horror, Mystery]
# 36  1698863816       97             [Animation, Adventure, Comedy, Family]
# 37   462180717      148                         [Action, Adventure, Drama]
# 38    17660107       85                    [Animation, Fantasy, Adventure]
# 39    59184643      127                      [Action, Adventure, Thriller]
#
#     popularity  vote_average  vote_count original_language  \
# 0     198.1218         6.200           2                pt
# 1     152.7018         7.500        6518                en
# 2     149.1418         7.049          41                ko
# 3     146.2852         5.870          23                fr
# 4     118.3758         7.080        2402                en
# 5     117.7351         4.600          11                en
# 6     102.2868         5.423          26                en
# 7      96.6719         0.000           0                ru
# 8      84.8384         7.392        2144                en
# 9      85.6323         7.500        4279                en
# 10     82.8014         6.618        6001                en
# 11     80.9869         7.719        2613                en
# 12     76.0191         6.662        1492                en
# 13     75.7244         6.123        3634                en
# 14     67.9292         5.750           8                en
# 15     64.4726         6.944          18                ko
# 16     63.9125         5.942        4422                en
# 17     61.6177         7.807        3695                es
# 18     60.5271         3.100           4                en
# 19     58.1097         8.300        4954                en
# 20     58.1030         6.863          40                en
# 21     55.2794         6.049         182                es
# 22     53.5862         6.276        4325                en
# 23     53.1377         8.130        1743                en
# 24     52.8382         6.737        3399                en
# 25     52.2778         7.230         791                fr
# 26     51.4752         5.413          52                en
# 27     51.2532         7.600        7278                en
# 28     47.3979         6.121        4102                en
# 29     50.3127         6.959         194                te
# 30     49.8121         5.500          12                en
# 31     48.7243         7.062        3085                en
# 32     48.2014         7.042        2774                en
# 33     48.1306         7.139        4662                en
# 34     43.6850         6.294          17                es
# 35     47.6771         5.608        3464                en
# 36     46.0900         7.555        5871                en
# 37     44.4574         6.736        3404                en
# 38     44.3366         8.177        1983                lv
# 39     44.8546         6.560        1707                en
#
#                                  production_companies  belongs_to_collection  \
# 0                                                  []                  False
# 1   [Walt Disney Pictures, Walt Disney Feature Ani...                   True
# 2              [Studio N, Oscar 10 Studio, Vol Media]                  False
# 3                       [MC4, Gébéka Films, Kinology]                  False
# 4   [Walt Disney Pictures, Walt Disney Animation S...                   True
# 5                                                  []                  False
# 6                            [7th Street Productions]                  False
# 7   [Central Partnership, Okko Studios, Cinema Fou...                  False
# 8                              [Walt Disney Pictures]                   True
# 9   [Paramount Pictures, Skydance Media, TC Produc...                   True
# 10  [Hard Eight Pictures, New Line Cinema, Zide-Pe...                   True
# 11  [Paramount Pictures, Original Film, Marza Anim...                   True
# 12  [Disney Television Animation, DisneyToon Studi...                   True
# 13  [Parallel Zide, New Line Cinema, Practical Pic...                   True
# 14  [Channel 4 Television, Out of the Blue Product...                  False
# 15                                                 []                  False
# 16  [Columbia Pictures, Original Film, Revolution ...                   True
# 17                  [Pokeepsie Films, Amazon Studios]                   True
# 18                                                 []                  False
# 19                             [DreamWorks Animation]                   True
# 20                                    [Black Mandala]                  False
# 21  [Versus Entertainment, LyO Media, Warner Bros....                  False
# 22          [New Line Cinema, Zide-Perry Productions]                   True
# 23  [SK Global Entertainment, Sidney Kimmel Entert...                  False
# 24  [Columbia Pictures, Pascal Pictures, Matt Tolm...                   True
# 25  [Trésor Films, Chi-Fou-Mi Productions, StudioC...                  False
# 26                                    [MSR Media SKN]                  False
# 27  [Marvel Studios, Maximum Effort, 21 Laps Enter...                   True
# 28  [New Line Cinema, Zide-Perry Productions, Hard...                   True
# 29                    [N. T. R. Arts, Yuvasudha Arts]                   True
# 30                           [AKOOLFILM COMPANY INC.]                  False
# 31                             [DreamWorks Animation]                   True
# 32                 [Universal Pictures, Illumination]                   True
# 33  [Working Title Films, Blacksmith, Working Titl...                  False
# 34  [Cotas Films, MGC Marketing Producción, Wild L...                  False
# 35  [Parallel Zide, New Line Cinema, Practical Pic...                   True
# 36                      [Walt Disney Pictures, Pixar]                   True
# 37  [Paramount Pictures, Scott Free Productions, L...                   True
# 38  [Dream Well Studio, Sacrebleu Productions, Tak...                  False
# 39  [Columbia Pictures, Matt Tolmach Productions, ...                  False
#
#                  director               lead_actor
# 0                    None                     None
# 1           Chris Sanders            Daveigh Chase
# 2            Park Jin-pyo             Shin Hye-sun
# 3          Michel Fessler            Mylène Farmer
# 4    David G. Derrick Jr.          Auliʻi Cravalho
# 5               Jon Cohen              Tim Spriggs
# 6   Calvin Morie McCarthy               Neil Green
# 7        Григорий Вожакин              Ivan Chaban
# 8           Barry Jenkins             Aaron Pierre
# 9   Christopher McQuarrie               Tom Cruise
# 10             James Wong               Devon Sawa
# 11            Jeff Fowler               Jim Carrey
# 12         Michael LaBash            Chris Sanders
# 13           Steven Quale        Nicholas D'Agosto
# 14          Mike Nicholls                Matt Barr
# 15          Lee Dong-Joon                  Lee Soo
# 16              Rob Cohen               Vin Diesel
# 17       Domingo González           Nicole Wallace
# 18           Mike Sargent              Keith David
# 19          Chris Sanders           Lupita Nyong'o
# 20         Gonzalo Mellid           Raymond E. Lee
# 21          Lucía Alemany         Gabriela Andrada
# 22         David R. Ellis               Ali Larter
# 23         Fisher Stevens        Justin Timberlake
# 24           Kelly Marcel                Tom Hardy
# 25       Gilles Lellouche      Adèle Exarchopoulos
# 26            Brad Watson            Daniel Stisen
# 27             Shawn Levy            Ryan Reynolds
# 28             James Wong  Mary Elizabeth Winstead
# 29          Koratala Siva        N.T. Rama Rao Jr.
# 30             Allen Kool             Jen Gardiner
# 31          Mike Mitchell               Jack Black
# 32           Chris Renaud             Steve Carell
# 33        Coralie Fargeat               Demi Moore
# 34          Sergio Pereda           Rodrigo Prieto
# 35         David R. Ellis              Bobby Campo
# 36            Kelsey Mann              Amy Poehler
# 37           Ridley Scott              Paul Mescal
# 38       Gints Zilbalodis                     None
# 39           J.C. Chandor     Aaron Taylor-Johnson

# %%
df_movies = df_movies[(df_movies["budget"] > 0) & (df_movies["revenue"] > 0)]

df_movies
# Out:
#                                             title release_date     budget  \
# 1                                   Lilo & Stitch   2002-06-21   80000000
# 4                                         Moana 2   2024-11-21  150000000
# 8                           Mufasa: The Lion King   2024-12-18  200000000
# 9   Mission: Impossible - Dead Reckoning Part One   2023-07-08  291000000
# 10                              Final Destination   2000-03-17   23000000
# 11                           Sonic the Hedgehog 3   2024-12-19  122000000
# 13                            Final Destination 5   2011-08-12   40000000
# 16                                            xXx   2002-08-09   70000000
# 19                                 The Wild Robot   2024-09-12   78000000
# 22                            Final Destination 2   2003-01-31   26000000
# 24                          Venom: The Last Dance   2024-10-22  120000000
# 25                                 Beating Hearts   2024-10-16   37315205
# 27                           Deadpool & Wolverine   2024-07-24  200000000
# 28                            Final Destination 3   2006-02-09   25000000
# 29                                 Devara: Part 1   2024-09-26   31764000
# 31                                Kung Fu Panda 4   2024-03-02   80000000
# 32                                Despicable Me 4   2024-06-20  100000000
# 33                                  The Substance   2024-09-07   17500000
# 35                          The Final Destination   2009-08-26   40000000
# 36                                   Inside Out 2   2024-06-11  200000000
# 37                                   Gladiator II   2024-11-13  310000000
# 38                                           Flow   2024-08-29    3700000
# 39                              Kraven the Hunter   2024-12-11  120000000
#
#        revenue  runtime                                             genres  \
# 1    273144151       85                        [Animation, Family, Comedy]
# 4   1059544057      100             [Animation, Adventure, Family, Comedy]
# 8    721046090      118                     [Adventure, Family, Animation]
# 9    571125435      164                      [Action, Adventure, Thriller]
# 10   112880294       98                                           [Horror]
# 11   486018457      110          [Action, Science Fiction, Comedy, Family]
# 13   157887643       91                                  [Horror, Mystery]
# 16   277448382      124               [Action, Adventure, Thriller, Crime]
# 19   331982078      102               [Animation, Science Fiction, Family]
# 22    90941129       90                                  [Horror, Mystery]
# 24   478103649      109               [Action, Science Fiction, Adventure]
# 25    36010728      166                            [Crime, Drama, Romance]
# 27  1338073645      128                  [Action, Comedy, Science Fiction]
# 28   118890272       92                                  [Horror, Mystery]
# 29    49520000      175                                    [Action, Drama]
# 31   548040835       94  [Animation, Family, Action, Comedy, Adventure,...
# 32   969280910       94       [Animation, Family, Comedy, Science Fiction]
# 33    76506196      141                          [Horror, Science Fiction]
# 35   187384627       82                                  [Horror, Mystery]
# 36  1698863816       97             [Animation, Adventure, Comedy, Family]
# 37   462180717      148                         [Action, Adventure, Drama]
# 38    17660107       85                    [Animation, Fantasy, Adventure]
# 39    59184643      127                      [Action, Adventure, Thriller]
#
#     popularity  vote_average  vote_count original_language  \
# 1     152.7018         7.500        6518                en
# 4     118.3758         7.080        2402                en
# 8      84.8384         7.392        2144                en
# 9      85.6323         7.500        4279                en
# 10     82.8014         6.618        6001                en
# 11     80.9869         7.719        2613                en
# 13     75.7244         6.123        3634                en
# 16     63.9125         5.942        4422                en
# 19     58.1097         8.300        4954                en
# 22     53.5862         6.276        4325                en
# 24     52.8382         6.737        3399                en
# 25     52.2778         7.230         791                fr
# 27     51.2532         7.600        7278                en
# 28     47.3979         6.121        4102                en
# 29     50.3127         6.959         194                te
# 31     48.7243         7.062        3085                en
# 32     48.2014         7.042        2774                en
# 33     48.1306         7.139        4662                en
# 35     47.6771         5.608        3464                en
# 36     46.0900         7.555        5871                en
# 37     44.4574         6.736        3404                en
# 38     44.3366         8.177        1983                lv
# 39     44.8546         6.560        1707                en
#
#                                  production_companies  belongs_to_collection  \
# 1   [Walt Disney Pictures, Walt Disney Feature Ani...                   True
# 4   [Walt Disney Pictures, Walt Disney Animation S...                   True
# 8                              [Walt Disney Pictures]                   True
# 9   [Paramount Pictures, Skydance Media, TC Produc...                   True
# 10  [Hard Eight Pictures, New Line Cinema, Zide-Pe...                   True
# 11  [Paramount Pictures, Original Film, Marza Anim...                   True
# 13  [Parallel Zide, New Line Cinema, Practical Pic...                   True
# 16  [Columbia Pictures, Original Film, Revolution ...                   True
# 19                             [DreamWorks Animation]                   True
# 22          [New Line Cinema, Zide-Perry Productions]                   True
# 24  [Columbia Pictures, Pascal Pictures, Matt Tolm...                   True
# 25  [Trésor Films, Chi-Fou-Mi Productions, StudioC...                  False
# 27  [Marvel Studios, Maximum Effort, 21 Laps Enter...                   True
# 28  [New Line Cinema, Zide-Perry Productions, Hard...                   True
# 29                    [N. T. R. Arts, Yuvasudha Arts]                   True
# 31                             [DreamWorks Animation]                   True
# 32                 [Universal Pictures, Illumination]                   True
# 33  [Working Title Films, Blacksmith, Working Titl...                  False
# 35  [Parallel Zide, New Line Cinema, Practical Pic...                   True
# 36                      [Walt Disney Pictures, Pixar]                   True
# 37  [Paramount Pictures, Scott Free Productions, L...                   True
# 38  [Dream Well Studio, Sacrebleu Productions, Tak...                  False
# 39  [Columbia Pictures, Matt Tolmach Productions, ...                  False
#
#                  director               lead_actor
# 1           Chris Sanders            Daveigh Chase
# 4    David G. Derrick Jr.          Auliʻi Cravalho
# 8           Barry Jenkins             Aaron Pierre
# 9   Christopher McQuarrie               Tom Cruise
# 10             James Wong               Devon Sawa
# 11            Jeff Fowler               Jim Carrey
# 13           Steven Quale        Nicholas D'Agosto
# 16              Rob Cohen               Vin Diesel
# 19          Chris Sanders           Lupita Nyong'o
# 22         David R. Ellis               Ali Larter
# 24           Kelly Marcel                Tom Hardy
# 25       Gilles Lellouche      Adèle Exarchopoulos
# 27             Shawn Levy            Ryan Reynolds
# 28             James Wong  Mary Elizabeth Winstead
# 29          Koratala Siva        N.T. Rama Rao Jr.
# 31          Mike Mitchell               Jack Black
# 32           Chris Renaud             Steve Carell
# 33        Coralie Fargeat               Demi Moore
# 35         David R. Ellis              Bobby Campo
# 36            Kelsey Mann              Amy Poehler
# 37           Ridley Scott              Paul Mescal
# 38       Gints Zilbalodis                     None
# 39           J.C. Chandor     Aaron Taylor-Johnson

# %%
row_count = len(df_movies)
print(f"Total movies with budget and revenue: {row_count}")
# Out:
# Total movies with budget and revenue: 23
